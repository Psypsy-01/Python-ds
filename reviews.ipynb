# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reviews=pd.read_csv('Reviews.csv')

# %%
reviews.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
reviews.isnull()
# Out:
#            Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# 0       False      False   False        False                 False
# 1       False      False   False        False                 False
# 2       False      False   False        False                 False
# 3       False      False   False        False                 False
# 4       False      False   False        False                 False
# ...       ...        ...     ...          ...                   ...
# 568449  False      False   False        False                 False
# 568450  False      False   False        False                 False
# 568451  False      False   False        False                 False
# 568452  False      False   False        False                 False
# 568453  False      False   False        False                 False
#
#         HelpfulnessDenominator  Score   Time  Summary   Text
# 0                        False  False  False    False  False
# ...

# %%
sns.heatmap(reviews.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [raw]
# The heatmap shows no data is missing

# %%
sns.distplot(reviews['Score'],bins=10)
plt.show()
# Out:
# C:\Users\acer12\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
reviews.sort_values(by='HelpfulnessNumerator',ascending=False)
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 190733  190734  B000FI4O90  A1GQGYROVZVW49                      P. Schmidt
# 207712  207713  B00012182G  A1JUGIQDY6UYSM           BabbChuck "BabbChuck"
# 566779  566780  B001PQTYN2  A1QB2Y8GSME58Y               Benjamin Chodroff
# 235722  235723  B001F10XUU  A39V22BIBUMMB3       Y. Hughes "Notmyrealname"
# 210511  210512  B005FKRTO0  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# ...        ...         ...             ...                             ...
# 246685  246686  B007M8FRU6  A1W5HSL3YBS265                      Lucky Lisa
# 246682  246683  B002Z05Z6C  A2KO345WG491BW                   Fraulein Grey
# 246681  246682  B002Z05Z6C   AQM475XS3T3Z7                 Elizabeth Short
# 246678  246679  B003WSNDMY  A31QXJGLKSH2UD                      LORDJOEYTX
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                        srfell17
#
# ...

# %%
sns.jointplot(x='HelpfulnessNumerator',y='Score',data=reviews,kind='reg')

# %%
reviews.drop_duplicates(subset ="UserId",keep = False, inplace = True)

# %%
def time(x):
    datetime.datetime.fromtimestamp(x)
reviews["Time"]= reviews["Time"].map(time) 
reviews.head()

# %%
reviews

# %%
from collections import Counter
rep = Counter()
reviews['Text'].str.lower().str.split().apply(rep.update)
rep.most_common(20)
# Out:
# [('the', 488014),
#  ('i', 404749),
#  ('and', 332512),
#  ('a', 300286),
#  ('to', 269722),
#  ('it', 221596),
#  ('of', 193396),
#  ('is', 183949),
#  ('this', 179026),
#  ('in', 145870),
#  ('for', 145600),
#  ('my', 122002),
#  ('that', 101075),
#  ('was', 99388),
#  ('have', 93458),
#  ('with', 89345),
#  ('but', 88395),
#  ('not', 82434),
#  ('you', 79353),
#  ('they', 72789)]

# %%
graph = sns.countplot(x="Score", data=reviews)
plt.title('Distribution of scores')
plt.xlabel('Rating')
plt.ylabel('Count')

for p in graph.patches:
        graph.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %%
labels = '1', '2', '3', '4','5'
sizes = [19938, 8865, 10471, 20132,115985]
colors = ['red', 'blue', 'orange', 'yellow', 'gold']
explode = (0.2, 0, 0, 0,0.4) 

plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=False)
plt.axis('equal')
plt.show()
